# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data =pd.read_csv('employee-compensation.csv')
data.head()
# Out:
#    Organization Group Code Job Family Code Job Code Year Type  Year  \
# 0                        1            1000     1021  Calendar  2013
# 1                        1            1000     1023  Calendar  2013
# 2                        1            1000     1031  Calendar  2013
# 3                        1            1000     1054  Calendar  2013
# 4                        1            1000     1062  Calendar  2013
#
#   Organization Group Department Code           Department  Union Code  \
# 0  Public Protection             ADP  ADP Adult Probation        21.0
# 1  Public Protection             ADP  ADP Adult Probation        21.0
# 2  Public Protection             ADP  ADP Adult Probation        21.0
# 3  Public Protection             ADP  ADP Adult Probation        21.0
# 4  Public Protection             ADP  ADP Adult Probation        21.0
#
#                                              Union  ... Employee Identifier  \
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(data.corr(),annot = True)
plt.title("Correlation heatmap:- ")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683277 entries, 0 to 683276
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Organization Group Code  683277 non-null  int64
#  1   Job Family Code          683277 non-null  object
#  2   Job Code                 683277 non-null  object
#  3   Year Type                683277 non-null  object
#  4   Year                     683277 non-null  int64
#  5   Organization Group       683277 non-null  object
#  6   Department Code          683275 non-null  object
#  7   Department               683275 non-null  object
#  8   Union Code               682926 non-null  float64
#  9   Union                    682926 non-null  object
#  10  Job Family               683277 non-null  object
#  11  Job                      683272 non-null  object
#  12  Employee Identifier      683277 non-null  int64
# ...

# %%
data_selected = ["Salaries", "Overtime","Other Salaries", "Total Salary","Retirement","Health and Dental","Other Benefits", "Total Benefits", "Total Compensation"]

# %%
pd.DataFrame(data,columns=data_selected)
# Out:
#          Salaries  Overtime  Other Salaries  Total Salary  Retirement  \
# 0        57534.65       0.0            0.00      57534.65    11253.16
# 1        57678.50       0.0            0.00      57678.50    10284.88
# 2        63532.93       0.0            0.00      63532.93    12495.83
# 3       101274.51       0.0        -7058.59      94215.92    19644.45
# 4         5084.00       0.0            0.00       5084.00     1083.90
# ...           ...       ...             ...           ...         ...
# 683272   98444.94       0.0            0.00      98444.94    20540.24
# 683273    9416.71       0.0            0.00       9416.71     1904.43
# 683274   96475.00       0.0          576.00      97051.00    20241.56
# 683275  115943.00       0.0            0.00     115943.00    24188.37
# 683276  115943.00     504.9            0.00     116447.90    24188.37
#
#         Health and Dental  Other Benefits  Total Benefits  Total Compensation
# ...

# %%
data['Salaries'][0]+data['Overtime'][0]+data['Other Salaries'][0]+data['Retirement'][0]+data['Health and Dental'][0]+data['Other Benefits'][0]
# Out:
# 85281.78

# %%
data.drop(['Year Type','Job Family Code','Union Code'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 data.drop(['Year Type','Job Family Code','Union Code'], axis = 1, inplace = True)
#
# File C:\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python\Python39\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
data.columns
# Out:
# Index(['Organization Group Code', 'Job Code', 'Year', 'Organization Group',
#        'Department Code', 'Department', 'Union', 'Job Family', 'Job',
#        'Employee Identifier', 'Salaries', 'Overtime', 'Other Salaries',
#        'Total Salary', 'Retirement', 'Health and Dental', 'Other Benefits',
#        'Total Benefits', 'Total Compensation'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683277 entries, 0 to 683276
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Organization Group Code  683277 non-null  int64
#  1   Job Code                 683277 non-null  object
#  2   Year                     683277 non-null  int64
#  3   Organization Group       683277 non-null  object
#  4   Department Code          683275 non-null  object
#  5   Department               683275 non-null  object
#  6   Union                    682926 non-null  object
#  7   Job Family               683277 non-null  object
#  8   Job                      683272 non-null  object
#  9   Employee Identifier      683277 non-null  int64
#  10  Salaries                 683277 non-null  float64
#  11  Overtime                 683277 non-null  float64
#  12  Other Salaries           683277 non-null  float64
# ...

# %%
data.shape
# Out:
# (683277, 19)

# %%
data.isnull().sum()
# Out:
# Organization Group Code      0
# Job Code                     0
# Year                         0
# Organization Group           0
# Department Code              2
# Department                   2
# Union                      351
# Job Family                   0
# Job                          5
# Employee Identifier          0
# Salaries                     0
# Overtime                     0
# Other Salaries               0
# Total Salary                 0
# Retirement                   0
# Health and Dental            0
# Other Benefits               0
# Total Benefits               0
# Total Compensation           0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Organization Group Code    0
# Job Code                   0
# Year                       0
# Organization Group         0
# Department Code            0
# Department                 0
# Union                      0
# Job Family                 0
# Job                        0
# Employee Identifier        0
# Salaries                   0
# Overtime                   0
# Other Salaries             0
# Total Salary               0
# Retirement                 0
# Health and Dental          0
# Other Benefits             0
# Total Benefits             0
# Total Compensation         0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df = data.drop(['Organization Group Code', 'Job Code', 'Year', 'Organization Group',
       'Department Code', 'Department', 'Union', 'Job Family', 'Job',
       'Employee Identifier', 'Salaries', 'Overtime', 'Other Salaries',
       'Total Salary', 'Retirement', 'Health and Dental', 'Other Benefits',
       'Total Benefits'],axis=1)
df['Retirement_and_Health'] = data['Retirement'] + data['Health and Dental']
df.head()
# Out:
#    Total Compensation  Retirement_and_Health
# 0            85281.78               23214.50
# 1            79895.32               17461.68
# 2            93649.71               25414.07
# 3           134237.37               32562.69
# 4             7512.31                2040.81

# %%
sns.distplot(df['Total Compensation'])
# Out:
# C:\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Compensation', ylabel='Density'>
